# %%
#from nltk.corpus import wordnet 


from nltk.corpus import wordnet as wn
from itertools import product


test_list=['hello','larissa','commoestas','salut','bueno']
remove_list=['hello','salut']

#[x for x in a if x not in [2, 3, 7]]
#remove a list from a list
res = [i for i in test_list if i not in remove_list] 
#print (res)


#remove 
import difflib
test_list2= ['djougue basso','djouguwbasso','sjougue', 'djouguea', 'puppy','hola','larissa','djoufack']
param = 'djougue'
for i in test_list2:
    print("value of i is:",i)
    remove_list2 = difflib.get_close_matches(i,test_list2)
    print()
    print("similar words:",remove_list2)
    test_list2 = [i for i in test_list2 if i not in remove_list2] 
   
    #print("current list: ",test_list2)
    print()
    print()
    print()
   # print('synonyms of:',i,'are:')
    print()
    wordnet.synsets(i) 
    
#difflib.get_close_matches(param, ['ape', 'apple', 'peach', 'puppy'])




    
    
""""""

word = 'socialist'
words = 'echo'
print(is_similar(word,words))



#>>> from nltk.corpus import wordnet
tardy_synsets = wordnet.synsets('tardy')
tardy_synsets[0].hypernyms()

print tardy_synsets[0].lch_similarity(tardy_synsets[0])

""""""
# Out:
# value of i is: djougue basso
#
# similar words: ['djougue basso', 'djouguwbasso', 'djouguea']
#
#
#
#
# value of i is: djouguwbasso
#
# similar words: []
#
#
#
#
# value of i is: sjougue
#
# similar words: ['sjougue']
#
#
#
#
# value of i is: djouguea
#
# similar words: ['djoufack']
#
#
#
#
# value of i is: puppy
#
# similar words: ['puppy']
#
#
#
#
# value of i is: hola
#
# similar words: ['hola']
#
#
#
#
# value of i is: larissa
#
# similar words: ['larissa']
#
#
#
#
# value of i is: djoufack
#
# similar words: []
